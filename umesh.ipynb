# %% [markdown]
# <a href="https://colab.research.google.com/github/Umeshserakula/Amazon/blob/main/umesh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Identifying Most Reviewed Product from Amazon DataSet of 35000 approx. reviews
# We've dataset from amazon with reviews of many products, <br>out of them we need to know which are the most reviewed products?<br>
# Let's look at dataset and see how we can do this!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv("/content/1429_1.csv", dtype='unicode')
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                reviews.date     reviews.dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 3  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 4  2017-01-12T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                     reviews.dateSeen  ... reviews.doRecommend  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                TRUE
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                TRUE
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                TRUE
# 3  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                TRUE
# 4  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...                TRUE
#
#   reviews.id reviews.numHelpful reviews.rating  \
# 0        NaN                  0              5
# 1        NaN                  0              5
# 2        NaN                  0              5
# 3        NaN                  0              4
# 4        NaN                  0              5
#
#                                   reviews.sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
# 3  http://reviews.bestbuy.com/3545/5620406/review...
# 4  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                         reviews.text  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                              reviews.title reviews.userCity  \
# 0                                   Kindle              NaN
# 1                                very fast              NaN
# 2  Beginner tablet for our 9 year old son.              NaN
# 3                                  Good!!!              NaN
# 4                Fantastic Tablet for kids              NaN
#
#   reviews.userProvince reviews.username
# 0                  NaN          Adapter
# 1                  NaN           truman
# 2                  NaN            DaveZ
# 3                  NaN           Shacks
# 4                  NaN        explore42
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Lookup
# After looking at data from dataset, it's look like there are some NaN values in it which we don't require

# %%
df.shape
# Out:
# (15115, 21)

# %%
df.columns
# Out:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username'],
#       dtype='object')

# %%
df.tail()
# Out:
#                          id  \
# 15110  AVpjEN4jLJeJML43rpUe
# 15111  AVpjEN4jLJeJML43rpUe
# 15112  AVpjEN4jLJeJML43rpUe
# 15113  AVpjEN4jLJeJML43rpUe
# 15114  AVpjEN4jLJeJML43rpUe
#
#                                                     name       asins   brand  \
# 15110  Brand New Amazon Kindle Fire 16gb 7 Ips Displa...  B018Y225IA  Amazon
# 15111  Brand New Amazon Kindle Fire 16gb 7 Ips Displa...  B018Y225IA  Amazon
# 15112  Brand New Amazon Kindle Fire 16gb 7 Ips Displa...  B018Y225IA  Amazon
# 15113  Brand New Amazon Kindle Fire 16gb 7 Ips Displa...  B018Y225IA  Amazon
# 15114  Brand New Amazon Kindle Fire 16gb 7 Ips Displa...  B018Y225IA  Amazon
#
#                                               categories  \
# 15110  Computers/Tablets & Networking,Tablets & eBook...
# 15111  Computers/Tablets & Networking,Tablets & eBook...
# 15112  Computers/Tablets & Networking,Tablets & eBook...
# 15113  Computers/Tablets & Networking,Tablets & eBook...
# 15114  Computers/Tablets & Networking,Tablets & eBook...
#
#                                                     keys manufacturer  \
# 15110  841667103143,0841667103143,brandnewamazonkindl...       Amazon
# 15111  841667103143,0841667103143,brandnewamazonkindl...       Amazon
# 15112  841667103143,0841667103143,brandnewamazonkindl...       Amazon
# 15113  841667103143,0841667103143,brandnewamazonkindl...       Amazon
# 15114  841667103143,0841667103143,brandnewamazonkindl...       Amazon
#
#                    reviews.date reviews.dateAdded  \
# 15110  2017-01-16T00:00:00.000Z               NaN
# 15111  2017-01-16T00:00:00.000Z               NaN
# 15112  2017-01-16T00:00:00.000Z               NaN
# 15113  2017-01-16T00:00:00.000Z               NaN
# 15114  2017-01-17T00:00:00.000Z               NaN
#
#                                         reviews.dateSeen  ...  \
# 15110  2017-08-27T00:00:00Z,2017-08-09T00:00:00Z,2017...  ...
# 15111  2017-08-27T00:00:00Z,2017-08-09T00:00:00Z,2017...  ...
# 15112  2017-08-27T00:00:00Z,2017-08-09T00:00:00Z,2017...  ...
# 15113  2017-08-27T00:00:00Z,2017-08-09T00:00:00Z,2017...  ...
# 15114  2017-08-27T00:00:00Z,2017-08-09T00:00:00Z,2017...  ...
#
#       reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 15110                TRUE        NaN                  0              5
# 15111                TRUE        NaN                  0              4
# 15112                TRUE        NaN                  0              5
# 15113                TRUE        NaN                  0              5
# 15114                TRUE        NaN                  0              5
#
#                                       reviews.sourceURLs  \
# 15110  http://reviews.bestbuy.com/3545/5025500/review...
# 15111  http://reviews.bestbuy.com/3545/5025500/review...
# 15112  http://reviews.bestbuy.com/3545/5025500/review...
# 15113  http://reviews.bestbuy.com/3545/5025500/review...
# 15114  http://reviews.bestbuy.com/3545/5025500/review...
#
#                                             reviews.text  \
# 15110  Works well! We had one of the original fires a...
# 15111  This little tablet surprised me. I did not exp...
# 15112  This is a great tablet. There are thousands of...
# 15113  Killer tablet for the price. No issues running...
# 15114  I'm normally an Apple snob but needed a cheap ...
#
#                                         reviews.title reviews.userCity  \
# 15110                                  Great tablet!!              NaN
# 15111  Excellent for those entering the tablet world.              NaN
# 15112                                    Great tablet              NaN
# 15113                                 Another winner.              NaN
# 15114                            Functional at a good              NaN
#
#       reviews.userProvince reviews.username
# 15110                  NaN       beatle0331
# 15111                  NaN      Jabaraboosh
# 15112                  NaN           Elaine
# 15113                  NaN          tctapes
# 15114                  NaN              NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Changing Column Names
# As column names are lengthy and not informative, so we'll give some suitable names to them

# %%
df.columns = ['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer','date', 'dateAdded', 'dateSeen','isPurchase', 'isRecommended', 'reviewsId','numHelpful', 'rating', 'sourceURLs','reviewText', 'reviewTitle', 'city','userProvince', 'username']
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                        date             dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 3  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 4  2017-01-12T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                             dateSeen  ... isRecommended  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 3  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 4  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
#
#   reviewsId numHelpful rating  \
# 0       NaN          0      5
# 1       NaN          0      5
# 2       NaN          0      5
# 3       NaN          0      4
# 4       NaN          0      5
#
#                                           sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
# 3  http://reviews.bestbuy.com/3545/5620406/review...
# 4  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                           reviewText  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                                reviewTitle city userProvince   username
# 0                                   Kindle  NaN          NaN    Adapter
# 1                                very fast  NaN          NaN     truman
# 2  Beginner tablet for our 9 year old son.  NaN          NaN      DaveZ
# 3                                  Good!!!  NaN          NaN     Shacks
# 4                Fantastic Tablet for kids  NaN          NaN  explore42
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Handling Null values

# %%
df.reviewsId.dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# id               object
# name             object
# asins            object
# brand            object
# categories       object
# keys             object
# manufacturer     object
# date             object
# dateAdded        object
# dateSeen         object
# isPurchase       object
# isRecommended    object
# reviewsId        object
# numHelpful       object
# rating           object
# sourceURLs       object
# reviewText       object
# reviewTitle      object
# city             object
# userProvince     object
# username         object
# dtype: object

# %%
df.reviewsId.fillna(0.0)
df.head()
# Out:
# <ipython-input-12-4f37e2bcc0fb>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.reviewsId.fillna(0.0)
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# 0  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 1  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 2  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 3  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
# 4  841667104676,amazon/53004484,amazon/b01ahb9cn2...       Amazon
#
#                        date             dateAdded  \
# 0  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 1  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 2  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 3  2017-01-13T00:00:00.000Z  2017-07-03T23:33:15Z
# 4  2017-01-12T00:00:00.000Z  2017-07-03T23:33:15Z
#
#                                             dateSeen  ... isRecommended  \
# 0  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 1  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 2  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 3  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
# 4  2017-06-07T09:04:00.000Z,2017-04-30T00:45:00.000Z  ...          TRUE
#
#   reviewsId numHelpful rating  \
# 0       NaN          0      5
# 1       NaN          0      5
# 2       NaN          0      5
# 3       NaN          0      4
# 4       NaN          0      5
#
#                                           sourceURLs  \
# 0  http://reviews.bestbuy.com/3545/5620406/review...
# 1  http://reviews.bestbuy.com/3545/5620406/review...
# 2  http://reviews.bestbuy.com/3545/5620406/review...
# 3  http://reviews.bestbuy.com/3545/5620406/review...
# 4  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                           reviewText  \
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...
#
#                                reviewTitle city userProvince   username
# 0                                   Kindle  NaN          NaN    Adapter
# 1                                very fast  NaN          NaN     truman
# 2  Beginner tablet for our 9 year old son.  NaN          NaN      DaveZ
# 3                                  Good!!!  NaN          NaN     Shacks
# 4                Fantastic Tablet for kids  NaN          NaN  explore42
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Removal of unnecessary columns
# To identify most reviewed products, we don't required few columns, therefore we'll remove those columns from dataset

# %%
df.columns
# Out:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'date', 'dateAdded', 'dateSeen', 'isPurchase', 'isRecommended',
#        'reviewsId', 'numHelpful', 'rating', 'sourceURLs', 'reviewText',
#        'reviewTitle', 'city', 'userProvince', 'username'],
#       dtype='object')

# %%
import pandas as pd

# Assuming you already have the DataFrame 'df'

# Drop a column called 'keys'
df = df.drop('keys', axis=1)

# Drop a column called 'sourceURLs' in place (modifies df directly)
df.drop('sourceURLs', axis=1, inplace=True)

# Drop multiple columns 'dateAdded' and 'dateSeen' in place
df.drop(['dateAdded', 'dateSeen'], axis=1, inplace=True)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#   manufacturer                      date isPurchase isRecommended reviewsId  \
# 0       Amazon  2017-01-13T00:00:00.000Z        NaN          TRUE       NaN
# 1       Amazon  2017-01-13T00:00:00.000Z        NaN          TRUE       NaN
# 2       Amazon  2017-01-13T00:00:00.000Z        NaN          TRUE       NaN
# 3       Amazon  2017-01-13T00:00:00.000Z        NaN          TRUE       NaN
# 4       Amazon  2017-01-12T00:00:00.000Z        NaN          TRUE       NaN
#
#   numHelpful rating                                         reviewText  \
# 0          0      5  This product so far has not disappointed. My c...
# 1          0      5  great for beginner or experienced person. Boug...
# 2          0      5  Inexpensive tablet for him to use and learn on...
# 3          0      4  I've had my Fire HD 8 two weeks now and I love...
# 4          0      5  I bought this for my grand daughter when she c...
#
#                                reviewTitle city userProvince   username
# 0                                   Kindle  NaN          NaN    Adapter
# 1                                very fast  NaN          NaN     truman
# 2  Beginner tablet for our 9 year old son.  NaN          NaN      DaveZ
# 3                                  Good!!!  NaN          NaN     Shacks
# 4                Fantastic Tablet for kids  NaN          NaN  explore42

# %%
df.isPurchase.fillna(False,inplace=True)
df.reviewsId.fillna("",inplace=True)
df.city.fillna("",inplace=True)
df.userProvince.fillna("",inplace=True)
df.head()
# Out:
# <ipython-input-15-8b4b3ae83380>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.isPurchase.fillna(False,inplace=True)
# <ipython-input-15-8b4b3ae83380>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.isPurchase.fillna(False,inplace=True)
# <ipython-input-15-8b4b3ae83380>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.reviewsId.fillna("",inplace=True)
# <ipython-input-15-8b4b3ae83380>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.city.fillna("",inplace=True)
# <ipython-input-15-8b4b3ae83380>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.userProvince.fillna("",inplace=True)
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#   manufacturer                      date  isPurchase isRecommended reviewsId  \
# 0       Amazon  2017-01-13T00:00:00.000Z       False          TRUE
# 1       Amazon  2017-01-13T00:00:00.000Z       False          TRUE
# 2       Amazon  2017-01-13T00:00:00.000Z       False          TRUE
# 3       Amazon  2017-01-13T00:00:00.000Z       False          TRUE
# 4       Amazon  2017-01-12T00:00:00.000Z       False          TRUE
#
#   numHelpful rating                                         reviewText  \
# 0          0      5  This product so far has not disappointed. My c...
# 1          0      5  great for beginner or experienced person. Boug...
# 2          0      5  Inexpensive tablet for him to use and learn on...
# 3          0      4  I've had my Fire HD 8 two weeks now and I love...
# 4          0      5  I bought this for my grand daughter when she c...
#
#                                reviewTitle city userProvince   username
# 0                                   Kindle                      Adapter
# 1                                very fast                       truman
# 2  Beginner tablet for our 9 year old son.                        DaveZ
# 3                                  Good!!!                       Shacks
# 4                Fantastic Tablet for kids                    explore42

# %% [markdown]
# ## DataSet Statistics Lookup

# %%
df.describe(include='object')
# Out:
#                           id  \
# count                  15115
# unique                    16
# top     AVphgVaX1cnluZ0-DR74
# freq                   10966
#
#                                                      name       asins   brand  \
# count                                               15115       15113   15115
# unique                                                 18          15       1
# top     Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
# freq                                                10966       10966   15115
#
#                                                categories manufacturer  \
# count                                               15115        15115
# unique                                                 16            1
# top     Fire Tablets,Tablets,Computers & Tablets,All T...       Amazon
# freq                                                10966        15115
#
#                             date isRecommended reviewsId numHelpful rating  \
# count                      15104         14677     15115      14685  15087
# unique                       803             2         1         43      5
# top     2015-12-28T00:00:00.000Z          TRUE                    0      5
# freq                         606         13991     15115      12644   9278
#
#                                                reviewText   reviewTitle  \
# count                                               15114         15114
# unique                                              15114          8634
# top     This product so far has not disappointed. My c...  Great tablet
# freq                                                    1           491
#
#          city userProvince username
# count   15115        15115    15111
# unique      1            1    12583
# top                            Mike
# freq    15115        15115       52

# %% [markdown]
# Removal of rows which are affecting our estimation

# %%
df.dropna(subset=['name'],inplace=True)
df.describe(include='object')
# Out:
#                           id  \
# count                  15115
# unique                    16
# top     AVphgVaX1cnluZ0-DR74
# freq                   10966
#
#                                                      name       asins   brand  \
# count                                               15115       15113   15115
# unique                                                 18          15       1
# top     Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...  B018Y229OU  Amazon
# freq                                                10966       10966   15115
#
#                                                categories manufacturer  \
# count                                               15115        15115
# unique                                                 16            1
# top     Fire Tablets,Tablets,Computers & Tablets,All T...       Amazon
# freq                                                10966        15115
#
#                             date isRecommended reviewsId numHelpful rating  \
# count                      15104         14677     15115      14685  15087
# unique                       803             2         1         43      5
# top     2015-12-28T00:00:00.000Z          TRUE                    0      5
# freq                         606         13991     15115      12644   9278
#
#                                                reviewText   reviewTitle  \
# count                                               15114         15114
# unique                                              15114          8634
# top     This product so far has not disappointed. My c...  Great tablet
# freq                                                    1           491
#
#          city userProvince username
# count   15115        15115    15111
# unique      1            1    12583
# top                            Mike
# freq    15115        15115       52

# %% [markdown]
# ## List of most reviewed product with number of reviews per product

# %%
df['name'].value_counts()
# Out:
# name
# Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes Special Offers, Magenta                                                                                                                        10966
# All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Magenta                                                                                                        2814
# Brand New Amazon Kindle Fire 16gb 7 Ips Display Tablet Wifi 16 Gb Blue,,,                                                                                                                       627
# All-New Kindle E-reader - Black, 6 Glare-Free Touchscreen Display, Wi-Fi -  Includes Special Offers,,                                                                                           212
# Amazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,\nAmazon 5W USB Official OEM Charger and Power Adapter for Fire Tablets and Kindle eReaders,,,      201
# All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 32 GB - Includes Special Offers, Magenta                                                                                                         158
# Kindle Oasis E-reader with Leather Charging Cover - Merlot, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers,,                                                               67
# Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black,,,\nAmazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black,,,                                                                                       25
# Fire HD 8 Tablet with Alexa, 8 HD Display, 32 GB, Tangerine - with Special Offers,                                                                                                               14
# Kindle Keyboard,,,\nKindle Keyboard,,,                                                                                                                                                            9
# Kindle Oasis E-reader with Leather Charging Cover - Black, 6 High-Resolution Display (300 ppi), Wi-Fi - Includes Special Offers,,                                                                 6
# Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers,                                                                                                                6
# Certified Refurbished Amazon Fire TV (Previous Generation - 1st),,,\nCertified Refurbished Amazon Fire TV (Previous Generation - 1st),,,                                                          3
# Amazon Kindle Lighted Leather Cover,,,\nAmazon Kindle Lighted Leather Cover,,,                                                                                                                    2
# Amazon Kindle Fire Hd (3rd Generation) 8gb,,,\nAmazon Kindle Fire Hd (3rd Generation) 8gb,,,                                                                                                      2
# Amazon Kindle Lighted Leather Cover,,,\nKindle Keyboard,,,                                                                                                                                        1
# Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Black,,,\nFire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers",                                                         1
# Amazon Standing Protective Case for Fire HD 6 (4th Generation) - Black,,,\nAmazon Standing Protective Case for Fire HD 6 (4th Generation) - Black,,,                                              1
# Name: count, dtype: int64

# %% [markdown]
# # **Let's do sentiment analysis on reviews of these products**

# %%
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-9v9gnmet
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-9v9gnmet
#   Resolved https://github.com/huggingface/transformers.git to commit 51ed61e2f05176f81fa7c9decba10cc28e138f61
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.50.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.50.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.50.0.dev0) (2025.1.31)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.50.0.dev0-py3-none-any.whl size=10877635 sha256=14ec980220ec65c85e10b5461fdef2fd15b4d30c12c5744d44cb66b1cafe4615
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r00el4ax/wheels/32/4b/78/f195c684dd3a9ed21f3b39fe8f85b48df7918581b6437be143
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# Successfully installed transformers-4.50.0.dev0

# %% [markdown]
# # Let me make all the review positive and negative based on their ratings. Negative(<3) and Positive(>=3)

# %%
sdf = df[['rating','reviewText']]
sdf.head(2)
# Out:
#   rating                                         reviewText
# 0      5  This product so far has not disappointed. My c...
# 1      5  great for beginner or experienced person. Boug...

# %%
def assign_sentiment(rating):
  if float(rating) >= 3:
    return "Positive"
  else:
    return "Negative"
sdf['sentiment'] = sdf['rating'].apply(assign_sentiment)
sdf.head(3)
# Out:
# <ipython-input-21-a7018f5751d7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf['sentiment'] = sdf['rating'].apply(assign_sentiment)
#   rating                                         reviewText sentiment
# 0      5  This product so far has not disappointed. My c...  Positive
# 1      5  great for beginner or experienced person. Boug...  Positive
# 2      5  Inexpensive tablet for him to use and learn on...  Positive

# %%
sdf.drop('rating', inplace=True, axis=1)
sdf.head()
# Out:
# <ipython-input-22-b4194028c7a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf.drop('rating', inplace=True, axis=1)
#                                           reviewText sentiment
# 0  This product so far has not disappointed. My c...  Positive
# 1  great for beginner or experienced person. Boug...  Positive
# 2  Inexpensive tablet for him to use and learn on...  Positive
# 3  I've had my Fire HD 8 two weeks now and I love...  Positive
# 4  I bought this for my grand daughter when she c...  Positive

# %%
from transformers import pipeline
sent_analysis = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu

# %%
sdf['reviewText'] = sdf['reviewText'].astype(str)
sdf.head()
sdf = sdf[sdf['reviewText'].map(len) <= 2000]
sdf.head()
sdf.dropna(inplace=True)
sdf.reset_index(inplace=True, drop=True)
# Out:
# <ipython-input-24-fcae0b64b580>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf['reviewText'] = sdf['reviewText'].astype(str)
# <ipython-input-24-fcae0b64b580>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf.dropna(inplace=True)

# %%
actual_sentiment = sdf['sentiment']

# %%
predicted_sentiment = []
for review in sdf['reviewText']:
  predicted_sentiment.append(sent_analysis(review)[0]['label'])

# %%
predicted_output = pd.DataFrame(predicted_sentiment)
predicted_output[0] = predicted_output[0].str.title()
predicted_output.head()
# Out:
#           0
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
actual_output = pd.DataFrame(actual_sentiment)
actual_output.head()
# Out:
#   sentiment
# 0  Positive
# 1  Positive
# 2  Positive
# 3  Positive
# 4  Positive

# %%
from sklearn.metrics import classification_report
print(classification_report(actual_output['sentiment'], predicted_output[0], target_names=['Negative Reviews','Positive Reviews']))
# Out:
#                   precision    recall  f1-score   support
#
# Negative Reviews       0.15      0.83      0.25       469
# Positive Reviews       0.99      0.84      0.91     14633
#
#         accuracy                           0.84     15102
#        macro avg       0.57      0.84      0.58     15102
#     weighted avg       0.97      0.84      0.89     15102
